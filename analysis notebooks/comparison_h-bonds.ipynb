# %%
import MDAnalysis as mda
from MDAnalysis.analysis.hydrogenbonds import HydrogenBondAnalysis
import mdtraj as md
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
# Out:
# INFO:rdkit:Enabling RDKit 2023.03.3 jupyter extensions
# INFO:numexpr.utils:Note: NumExpr detected 20 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
#amber trajectories 100 ns 
u = mda.Universe("/pascal/data/project/100ns_prod_runs/prod_100ns_amber_lig_only_4000_1/amber_copy.parm7", "/pascal/data/project/100ns_prod_runs/prod_100ns_amber_lig_only_4000_1/amber.nc")
u_2 = mda.Universe("/pascal/data/project/100ns_prod_runs/prod_100ns_amber_lig_only_4000_2/amber_copy.parm7", "/pascal/data/project/100ns_prod_runs/prod_100ns_amber_lig_only_4000_2/amber.nc")
u_3 = mda.Universe("/pascal/data/project/100ns_prod_runs/prod_100ns_amber_lig_only_4000_3/amber_copy.parm7", "/pascal/data/project/100ns_prod_runs/prod_100ns_amber_lig_only_4000_3/amber.nc")

#espaloma traj
u_4 = mda.Universe("/pascal/data/project/espaloma/prod_100ns_4000/amber_copy.parm7", "/pascal/data/project/espaloma/prod_100ns_4000/amber.nc")
u_5 = mda.Universe("/pascal/data/project/espaloma/prod_100ns_4000_2/amber_copy.parm7", "/pascal/data/project/espaloma/prod_100ns_4000_2/amber.nc")
u_6 = mda.Universe("/pascal/data/project/espaloma/prod_100ns_4000_3/amber_copy.parm7", "/pascal/data/project/espaloma/prod_100ns_4000_3/amber.nc")

# %%
#amber trajectories 1000 ns
u = mda.Universe("/pascal/data/project/prod_runs/prod_1000ns_amber_lig_only_4000_1/amber_copy.parm7", "/pascal/data/project/prod_runs/prod_1000ns_amber_lig_only_4000_1/amber.nc")
u_2 = mda.Universe("/pascal/data/project/prod_runs/prod_1000ns_amber_lig_only_4000_2/amber_copy.parm7", "/pascal/data/project/prod_runs/prod_1000ns_amber_lig_only_4000_2/amber.nc")
u_3 = mda.Universe("/pascal/data/project/prod_runs/prod_1000ns_amber_lig_only_4000_3/amber_copy.parm7", "/pascal/data/project/prod_runs/prod_1000ns_amber_lig_only_4000_3/amber.nc")

#espaloma traj
u_4 = mda.Universe("/pascal/data/project/espaloma/prod_1000ns_40000/amber_copy.parm7", "/pascal/data/project/espaloma/prod_1000ns_40000/amber.nc")
u_5 = mda.Universe("/pascal/data/project/espaloma/prod_1000ns_40000_2/amber_copy.parm7", "/pascal/data/project/espaloma/prod_1000ns_40000_2/amber.nc")
u_6 = mda.Universe("/pascal/data/project/espaloma/prod_1000ns_40000_3/amber_copy.parm7", "/pascal/data/project/espaloma/prod_1000ns_40000_3/amber.nc")

# %% [markdown]
# Protein-ligand trajectories

# %%
#amber 100 ns trajectories of protein-ligand
u = mda.Universe("/pascal/data/project/100ns_prod_runs/prod_100ns_amber_4000_1/amber_copy.parm7", "/pascal/data/project/100ns_prod_runs/prod_100ns_amber_4000_1/amber.nc")
u_2 =mda.Universe("/pascal/data/project/100ns_prod_runs/prod_100ns_amber_4000_2/amber_copy.parm7", "/pascal/data/project/100ns_prod_runs/prod_100ns_amber_4000_2/amber.nc")
u_3 =mda.Universe("/pascal/data/project/100ns_prod_runs/prod_100ns_amber_4000_3/amber_copy.parm7", "/pascal/data/project/100ns_prod_runs/prod_100ns_amber_4000_3/amber.nc")

#espaloma traj
u_4 = mda.Universe("/pascal/data/project/protein_ligand/prod_100ns_esp_4000/amber_copy.parm7", "/pascal/data/project/protein_ligand/prod_100ns_esp_4000/amber.nc")
u_5 = mda.Universe("/pascal/data/project/protein_ligand/prod_100ns_esp_4000_2/amber_copy.parm7", "/pascal/data/project/protein_ligand/prod_100ns_esp_4000_2/amber.nc")
u_6 = mda.Universe("/pascal/data/project/protein_ligand/prod_100ns_esp_4000_3/amber_copy.parm7", "/pascal/data/project/protein_ligand/prod_100ns_esp_4000_3/amber.nc")

# %%
#amber trajectories 1000 ns protein-ligand
u = mda.Universe("/pascal/data/project/prod_runs/prod_1000ns_amber_4000_1/amber_copy.parm7", "/pascal/data/project/prod_runs/prod_1000ns_amber_4000_1/amber.nc")
u_2 =mda.Universe("/pascal/data/project/prod_runs/prod_1000ns_amber_4000_2/amber_copy.parm7", "/pascal/data/project/prod_runs/prod_1000ns_amber_4000_2/amber.nc")
u_3 =mda.Universe("/pascal/data/project/prod_runs/prod_1000ns_amber_4000_3/amber_copy.parm7", "/pascal/data/project/prod_runs/prod_1000ns_amber_4000_3/amber.nc")

#espaloma traj
u_4 = mda.Universe("/pascal/data/project/protein_ligand/prod_1000ns_esp_4000/amber_copy.parm7", "/pascal/data/project/protein_ligand/prod_1000ns_esp_4000/amber.nc")
u_5 = mda.Universe("/pascal/data/project/protein_ligand/prod_1000ns_esp_4000_2/amber_copy.parm7", "/pascal/data/project/protein_ligand/prod_1000ns_esp_4000_2/amber.nc")
u_6 = mda.Universe("/pascal/data/project/protein_ligand/prod_1000ns_esp_4000_3/amber_copy.parm7", "/pascal/data/project/protein_ligand/prod_1000ns_esp_4000_3/amber.nc")

# %% [markdown]
# H-bonds intramolecular

# %%
#h_bonds intramolecular selection guessing donors and acceptors

hbonds = HydrogenBondAnalysis(universe=u)
hbonds.hydrogens_sel = hbonds.guess_hydrogens("resid 1:12")
hbonds.acceptors_sel = hbonds.guess_acceptors("resid 1:12")

hbonds_2 = HydrogenBondAnalysis(universe=u_2)
hbonds_2.hydrogens_sel = hbonds_2.guess_hydrogens("resid 1:12")
hbonds_2.acceptors_sel = hbonds_2.guess_acceptors("resid 1:12")

hbonds_3 = HydrogenBondAnalysis(universe=u_3)
hbonds_3.hydrogens_sel = hbonds_3.guess_hydrogens("resid 1:12")
hbonds_3.acceptors_sel = hbonds_3.guess_acceptors("resid 1:12")

hbonds_4 = HydrogenBondAnalysis(universe=u_4)
hbonds_4.hydrogens_sel = hbonds_4.guess_hydrogens("resid 1")
hbonds_4.acceptors_sel = hbonds_4.guess_acceptors("resid 1")

hbonds_5 = HydrogenBondAnalysis(universe=u_5)
hbonds_5.hydrogens_sel = hbonds_5.guess_hydrogens("resid 1")
hbonds_5.acceptors_sel = hbonds_5.guess_acceptors("resid 1")

hbonds_6 = HydrogenBondAnalysis(universe=u_6)
hbonds_6.hydrogens_sel = hbonds_6.guess_hydrogens("resid 1")
hbonds_6.acceptors_sel = hbonds_6.guess_acceptors("resid 1")

# %%
between=[["resid 1:12", "resid 1:12"]]
between=[["index 0:175", "index 0:175"]]

# %%
traj = u.trajectory
print(len(traj))
drop_frames = int(traj.n_frames * 0.05)
print(drop_frames)
# Out:
# 4000
# 200

# %%
#for espaloma long trajs only 10 % of frames to be used -> edit drop frames below as well 
drop_frames_esp = drop_frames *10
print(drop_frames_esp)
# Out:
# 2000

# %%
hbonds.run(start=drop_frames,stop=None,step=None,verbose=True)
hbonds_2.run(start=drop_frames,stop=None,step=None,verbose=True)
hbonds_3.run(start=drop_frames,stop=None,step=None,verbose=True)
hbonds_4.run(start=drop_frames,stop=None,step=None,verbose=True)
hbonds_5.run(start=drop_frames,stop=None,step=None,verbose=True)
hbonds_6.run(start=drop_frames,stop=None,step=None,verbose=True)

# %%
#counting most common donors and acceptors (to be edited for amber or espaloma hbonds)

counts = hbonds_4.count_by_ids()
most_common = counts[0]

print(f"Most common donor espaloma 1: {u_4.atoms[most_common[0]]}")
print(f"Most common hydrogen espaloma 1: {u_4.atoms[most_common[1]]}")
print(f"Most common acceptor espaloma 1: {u_4.atoms[most_common[2]]}")

counts = hbonds_5.count_by_ids()
most_common = counts[0]

print(f"Most common donor espaloma 2: {u_5.atoms[most_common[0]]}")
print(f"Most common hydrogen espaloma 2: {u_5.atoms[most_common[1]]}")
print(f"Most common acceptor espaloma 2: {u_5.atoms[most_common[2]]}")

counts = hbonds_6.count_by_ids()
most_common = counts[0]

print(f"Most common donor espaloma 3: {u_6.atoms[most_common[0]]}")
print(f"Most common hydrogen espaloma 3: {u_6.atoms[most_common[1]]}")
print(f"Most common acceptor espaloma 3: {u_6.atoms[most_common[2]]}")
# Out:
# Most common donor espaloma 1: <Atom 86: C of type X86 of resname MOL0, resid 1 and segid SYSTEM>
# Most common hydrogen espaloma 1: <Atom 166: H of type X166 of resname MOL0, resid 1 and segid SYSTEM>
# Most common acceptor espaloma 1: <Atom 50: N of type X50 of resname MOL0, resid 1 and segid SYSTEM>

# %%
print(len(hbonds_4.count_by_time()))
# Out:
# 3800

# %%
df= pd.DataFrame()
df["Counts"] = hbonds.count_by_time()
df['FF'] = 'Amber'

df_2= pd.DataFrame()
df_2["Counts"] = hbonds_2.count_by_time()

df_3= pd.DataFrame()
df_3["Counts"] = hbonds_3.count_by_time()

df_4= pd.DataFrame()
df_4["Counts"] = hbonds_4.count_by_time()

df_5= pd.DataFrame()
df_5["Counts"] = hbonds_5.count_by_time()

df_6= pd.DataFrame()
df_6["Counts"] = hbonds_6.count_by_time()
df
# Out:
#       Counts     FF
# 0          0  Amber
# 1          1  Amber
# 2          1  Amber
# 3          1  Amber
# 4          1  Amber
# ...      ...    ...
# 3795       1  Amber
# 3796       1  Amber
# 3797       0  Amber
# 3798       1  Amber
# 3799       0  Amber
#
# [3800 rows x 2 columns]

# %%
df_2['FF'] = 'Amber'
df_3['FF'] = 'Amber'
df_4['FF'] = 'espaloma 0.3.2'
df_5['FF'] = 'espaloma 0.3.2'
df_6['FF'] = 'espaloma 0.3.2'

# %%
full_df = pd.concat([df, df_2, df_3, df_4, df_5, df_6])
full_df
# Out:
#       Counts              FF
# 0          0           Amber
# 1          1           Amber
# 2          1           Amber
# 3          1           Amber
# 4          1           Amber
# ...      ...             ...
# 3795       0  espaloma 0.3.2
# 3796       0  espaloma 0.3.2
# 3797       1  espaloma 0.3.2
# 3798       1  espaloma 0.3.2
# 3799       1  espaloma 0.3.2
#
# [22800 rows x 2 columns]

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=full_df, x=((full_df.index)+drop_frames)/4, y="Counts", hue=full_df['FF'],alpha=0.7, estimator="mean", errorbar="sd")
plt.xlabel("Time (ns)")
#plt.suptitle("Intramolecular H-Bonds Compound 19 100 ns")
plt.suptitle("Intramolecular H-Bonds Compound 19 1 $\mu$s")
plt.xlim(50, 1000)
plt.ylim(bottom=0)
plt.ylabel("Count")
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.savefig("plots_newamber/Hbonds/intra_1000")

# %% [markdown]
# Intermolecular h-bonds

# %%
#intermolecular selection
protein_residues= u.select_atoms("resid 241 or resid 239 or resid 237")
compound_19 = u.select_atoms("resid 1:12")


protein_residues_esp= u_4.select_atoms("resid 230 or resid 228 or resid 226")
compound_19_esp =u_4.select_atoms("resid 1")
for a in protein_residues_esp:
    print(a)

# %%
#guessing donors and acceptors in either molecule 

hbonds = HydrogenBondAnalysis(universe=u, between=["resid 1:12", "resid 13:306"])
protein_hydrogens_sel_amb = hbonds.guess_hydrogens("resid 13:306")
protein_acceptors_sel_amb = hbonds.guess_acceptors("resid 13:306")

ligand_hydrogens_sel_amb = hbonds.guess_hydrogens("resid 1:12")
ligand_acceptors_sel_amb = hbonds.guess_acceptors("resid 1:12")

hbonds.hydrogens_sel = f"({protein_hydrogens_sel_amb}) or ({ligand_hydrogens_sel_amb})"
hbonds.acceptors_sel = f"({protein_acceptors_sel_amb}) or ({ligand_acceptors_sel_amb})"

#amber2
hbonds_2 = HydrogenBondAnalysis(universe=u_3, between=["resid 1:12", "resid 13:306"])
protein_hydrogens_sel_2 = hbonds_2.guess_hydrogens("resid 13:306")
protein_acceptors_sel_2 = hbonds_2.guess_acceptors("resid 13:306")

ligand_hydrogens_sel_2 = hbonds_2.guess_hydrogens("resid 1:12")
ligand_acceptors_sel_2 = hbonds_2.guess_acceptors("resid 1:12")

hbonds_2.hydrogens_sel = f"({protein_hydrogens_sel_2}) or ({ligand_hydrogens_sel_2})"
hbonds_2.acceptors_sel = f"({protein_acceptors_sel_2}) or ({ligand_acceptors_sel_2})"

#amber3
hbonds_3 = HydrogenBondAnalysis(universe=u_3, between=["resid 1:12", "resid 13:306"])
protein_hydrogens_sel_3 = hbonds_3.guess_hydrogens("resid 13:306")
protein_acceptors_sel_3 = hbonds_3.guess_acceptors("resid 13:306")

ligand_hydrogens_sel_3 = hbonds_3.guess_hydrogens("resid 1:12")
ligand_acceptors_sel_3 = hbonds_3.guess_acceptors("resid 1:12")

hbonds_3.hydrogens_sel = f"({protein_hydrogens_sel_3}) or ({ligand_hydrogens_sel_3})"
hbonds_3.acceptors_sel = f"({protein_acceptors_sel_3}) or ({ligand_acceptors_sel_3})"


#espaloma 1
hbonds_4 = HydrogenBondAnalysis(universe=u_4, between=["resid 1", "resid 2:295"])
protein_hydrogens_sel_4 = hbonds_4.guess_hydrogens("resid 2:295")
protein_acceptors_sel_4 = hbonds_4.guess_acceptors("resid 2:295")

ligand_hydrogens_sel_4 = hbonds_4.guess_hydrogens("resid 1")
ligand_acceptors_sel_4 = hbonds_4.guess_acceptors("resid 1")

hbonds_4.hydrogens_sel = f"({protein_hydrogens_sel_4}) or ({ligand_hydrogens_sel_4})"
hbonds_4.acceptors_sel = f"({protein_acceptors_sel_4}) or ({ligand_acceptors_sel_4})"


#espaloma 2
hbonds_5 = HydrogenBondAnalysis(universe=u_5, between=["resid 1", "resid 2:295"])
protein_hydrogens_sel_5 = hbonds_5.guess_hydrogens("resid 2:295")
protein_acceptors_sel_5 = hbonds_5.guess_acceptors("resid 2:295")

ligand_hydrogens_sel_5 = hbonds_5.guess_hydrogens("resid 1")
ligand_acceptors_sel_5 = hbonds_5.guess_acceptors("resid 1")

hbonds_5.hydrogens_sel = f"({protein_hydrogens_sel_5}) or ({ligand_hydrogens_sel_5})"
hbonds_5.acceptors_sel = f"({protein_acceptors_sel_5}) or ({ligand_acceptors_sel_5})"


#espaloma 3
hbonds_6 = HydrogenBondAnalysis(universe=u_6, between=["resid 1", "resid 2:295"])
protein_hydrogens_sel_6 = hbonds_6.guess_hydrogens("resid 2:295")
protein_acceptors_sel_6 = hbonds_6.guess_acceptors("resid 2:295")

ligand_hydrogens_sel_6 = hbonds_6.guess_hydrogens("resid 1")
ligand_acceptors_sel_6 = hbonds_6.guess_acceptors("resid 1")

hbonds_6.hydrogens_sel = f"({protein_hydrogens_sel_6}) or ({ligand_hydrogens_sel_6})"
hbonds_6.acceptors_sel = f"({protein_acceptors_sel_6}) or ({ligand_acceptors_sel_6})"

# %%
traj = u.trajectory
print(len(traj))
drop_frames = int(traj.n_frames * 0.05)
print(drop_frames)

# %%
hbonds.run(start=drop_frames,stop=None,step=None,verbose=True)
hbonds_2.run(start=drop_frames,stop=None,step=None,verbose=True)
hbonds_3.run(start=drop_frames,stop=None,step=None,verbose=True)
hbonds_4.run(start=drop_frames,stop=None,step=None,verbose=True)
hbonds_5.run(start=drop_frames,stop=None,step=None,verbose=True)
hbonds_6.run(start=drop_frames,stop=None,step=None,verbose=True)

# %%
#filtering out the wanted h-bonds by looking for 19 atoms from lit to be either donor or acceptor atom

df_1= pd.DataFrame(hbonds.results.hbonds)
filtered_df_1= df_1[(df_1.iloc[:,1]==35)|(df_1.iloc[:,1]==44)|(df_1.iloc[:,1]==64)|(df_1.iloc[:,1]==87)|(df_1.iloc[:,1]==100)
                    |(df_1.iloc[:,3]==35)|(df_1.iloc[:,3]==44) |(df_1.iloc[:,3]==64)|(df_1.iloc[:,3]==87)|(df_1.iloc[:,3]==100)]
filtered_df_1=filtered_df_1.rename(columns={filtered_df_1.column[0]:"Frame"})
hb_count_1 = pd.DataFrame(filtered_df_1.groupby("Frame").size())
hb_count_1["FF"]="Amber"

#amber2
df_2= pd.DataFrame(hbonds_2.results.hbonds)
filtered_df_2= df_2[(df_2.iloc[:,1]==35)|(df_2.iloc[:,1]==44)|(df_2.iloc[:,1]==64)|(df_2.iloc[:,1]==87)|(df_2.iloc[:,1]==100)
                    |(df_2.iloc[:,3]==35)|(df_2.iloc[:,3]==44) |(df_2.iloc[:,3]==64)|(df_2.iloc[:,3]==87)|(df_2.iloc[:,3]==100)]
filtered_df_2=filtered_df_2.rename(columns={filtered_df_2.column[0]:"Frame"})
hb_count_2 = pd.DataFrame(filtered_df_2.groupby("Frame").size())
hb_count_2["FF"]="Amber"

#amber3
df_3= pd.DataFrame(hbonds_3.results.hbonds)
filtered_df_3= df_3[(df_3.iloc[:,1]==35)|(df_3.iloc[:,1]==44)|(df_3.iloc[:,1]==64)|(df_3.iloc[:,1]==87)|(df_3.iloc[:,1]==100)
                    |(df_3.iloc[:,3]==35)|(df_3.iloc[:,3]==44) |(df_3.iloc[:,3]==64)|(df_3.iloc[:,3]==87)|(df_3.iloc[:,3]==100)]
filtered_df_3=filtered_df_3.rename(columns={filtered_df_3.column[0]:"Frame"})
hb_count_3 = pd.DataFrame(filtered_df_3.groupby("Frame").size())
hb_count_3["FF"]="Amber"

#espaloma1
df_4= pd.DataFrame(hbonds_4.results.hbonds)
filtered_df_4= df_4[(df_4.iloc[:,1]==18)|(df_4.iloc[:,1]==22)|(df_4.iloc[:,1]==34)|(df_4.iloc[:,1]==48)|(df_4.iloc[:,1]==52)
                    |(df_4.iloc[:,3]==18)|(df_4.iloc[:,3]==22) |(df_4.iloc[:,3]==34)|(df_4.iloc[:,3]==48)|(df_4.iloc[:,3]==52)]
filtered_df_4=filtered_df_4.rename(columns={filtered_df_4.column[0]:"Frame"})
hb_count_4 = pd.DataFrame(filtered_df_4.groupby("Frame").size())
hb_count_4["FF"]="espaloma 0.3.2"

#espaloma2
df_5= pd.DataFrame(hbonds_5.results.hbonds)
filtered_df_5= df_5[(df_5.iloc[:,1]==18)|(df_5.iloc[:,1]==22)|(df_5.iloc[:,1]==34)|(df_5.iloc[:,1]==48)|(df_5.iloc[:,1]==52)
                    |(df_5.iloc[:,3]==18)|(df_5.iloc[:,3]==22) |(df_5.iloc[:,3]==34)|(df_5.iloc[:,3]==48)|(df_5.iloc[:,3]==52)]
filtered_df_5=filtered_df_5.rename(columns={filtered_df_5.column[0]:"Frame"})
hb_count_5 = pd.DataFrame(filtered_df_5.groupby("Frame").size())
hb_count_5["FF"]="espaloma 0.3.2"

#espaloma3
df_6= pd.DataFrame(hbonds_6.results.hbonds)
filtered_df_6= df_6[(df_6.iloc[:,1]==18)|(df_6.iloc[:,1]==22)|(df_6.iloc[:,1]==34)|(df_6.iloc[:,1]==48)|(df_6.iloc[:,1]==52)
                    |(df_6.iloc[:,3]==18)|(df_6.iloc[:,3]==22) |(df_6.iloc[:,3]==34)|(df_6.iloc[:,3]==48)|(df_6.iloc[:,3]==52)]
filtered_df_6=filtered_df_6.rename(columns={filtered_df_6.column[0]:"Frame"})
hb_count_6 = pd.DataFrame(filtered_df_6.groupby("Frame").size())
hb_count_6["FF"]="espaloma 0.3.2"

# %%
full_df = pd.concat([hb_count_1, hb_count_2, hb_count_3, hb_count_4, hb_count_5, hb_count_6])

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=full_df, x=((full_df.index)+drop_frames)/4, y="Counts", hue=full_df['FF'],alpha=0.7, estimator="mean", errorbar="sd")
plt.xlabel("Time (ns)")
#plt.suptitle("Intermolecular H-Bonds Compound 19 100 ns")
plt.suptitle("Intermolecular H-Bonds Compound 19 1 $\mu$s")
plt.xlim(50, 1000)
plt.ylim(bottom=0)
plt.ylabel("Count")
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.savefig("plots_newamber/Hbonds/inter_1000")
